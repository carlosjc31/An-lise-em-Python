# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/carlo/Desktop/Machine Learning/Machine Learning/Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  Qty  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped    1
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped    1
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped    1
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped    1
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped    1
#
#        currency  Amount  ship-city    ship-state  ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.drop(['New','PendingS'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
# check shape values
df.shape
# Out:
# (128976, 19)

# %%
# drop null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (37514, 19)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
# change data type, ship-postal-code to int
df['ship-postal-code'] = df['ship-postal-code'].astype('int')

# %%
#change data type for 'int'
df['ship-postal-code'].dtype
# Out:
# dtype('int32')

# %%
#change data type for 'Date'
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_6100\3023999556.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])

# %%
df.rename(columns={'Qty':'Quantity'})
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.describe()
# Out:
#                index                           Date           Qty  \
# count   37514.000000                          37514  37514.000000
# mean    60953.809858  2022-05-11 07:56:47.303939840      0.867383
# min         0.000000            2022-03-31 00:00:00      0.000000
# 25%     27235.250000            2022-04-20 00:00:00      1.000000
# 50%     63470.500000            2022-05-09 00:00:00      1.000000
# 75%     91790.750000            2022-06-01 00:00:00      1.000000
# max    128891.000000            2022-06-29 00:00:00      5.000000
# std     36844.853039                            NaN      0.354160
#
#              Amount  ship-postal-code
# count  37514.000000      37514.000000
# mean     646.553960     463291.552754
# min        0.000000     110001.000000
# 25%      458.000000     370465.000000
# 50%      629.000000     500019.000000
# 75%      771.000000     600042.000000
# max     5495.000000     989898.000000
# std      279.952414     194550.425637

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 37514                         37514      37514
# unique                34664                            11          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         28741      37514
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          37514              37514    37514  37514          37514
# unique             1                  1        8     11              3
# top        Amazon.in           Standard  T-shirt      M        Shipped
# freq           37514              37514    14062   6806          31859
#
#        currency  ship-city   ship-state ship-country fulfilled-by
# count     37514      37514        37514        37514        37514
# unique        1       4698           58            1            1
# ...

# %%
df[['Qty','Amount']].describe()
# Out:
#                 Qty        Amount
# count  37514.000000  37514.000000
# mean       0.867383    646.553960
# std        0.354160    279.952414
# min        0.000000      0.000000
# 25%        1.000000    458.000000
# 50%        1.000000    629.000000
# 75%        1.000000    771.000000
# max        5.000000   5495.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
ax=sns.countplot(x='Size',data=df)

# %%
ax=sns.countplot(x='Size',data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# No gráfico acima, podemos verificar que o tamanho M, é o que mais vendeu.

# %% [markdown]
# Group BY

# %%
df.groupby(['Size'], as_index=False)['Qty'].sum().sort_values(by='Qty', ascending=False)
# Out:
#     Size    Qty
# 6      M  20138
# 5      L  19706
# 8     XL  18636
# 10   XXL  16246
# 7      S  15041
# 0    3XL  13360
# 9     XS   9850
# 4   Free   2070
# 3    6XL    688
# 2    5XL    513
# 1    4XL    398

# %%
qty=df.groupby(['Size'], as_index=False)['Qty'].sum().sort_values(by='Qty', ascending=False)

sns.barplot(x='Size', y='Qty', data=qty)
# Out:
# <Axes: xlabel='Size', ylabel='Qty'>

# %% [markdown]
# No gráfico acima, pode-se verificar que o tamanha 'M', possui maior vendas.

# %% [markdown]
# Abaixo o gráfico de Status das entregas.

# %%
sns.countplot(data=df, x='Courier Status', hue='Status')
# Out:
# <Axes: xlabel='Courier Status', ylabel='count'>

# %%
# É o mesmo gráfico acima, mas de uma forma mais ampliado.
plt.figure(figsize=(10,5))
ax = sns.countplot(data=df, x='Courier Status', hue='Status')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['Size'].hist()

plt.show()

# %% [markdown]
# No gráfico abaixo, observamos que os itens, mais vendidos, são camisas e camisetas(T-shirt and Shirt).

# %%
df['Category'] = df['Category'].astype(str) # transformando a coluna em string.
column_data = df['Category'] # selecionando a coluna.
plt.figure(figsize=(10,5)) # definindo o tamanho do gráfico.
plt.hist(column_data, bins=25, edgecolor='orange') # define o tamanho das barras e a cor de contorno
plt.xticks(rotation=45) # define a inclinação das categorias
plt.show()

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
#Outro formato de gráfico de visualizar o gáfico das entregas.
df['Status'] = df['Status'].astype(str)
column_data = df['Status']
plt.figure(figsize=(10,5))
plt.hist(column_data, bins=25, edgecolor='orange')
plt.xticks(rotation=60)
plt.show()

# %%
ship_data = df['ship-service-level'].value_counts()
plt.pie(ship_data, labels=ship_data.index, autopct='%1.1f%%')
plt.show()

# %%
ab = df['Fulfilment'].value_counts()

fig, ax = plt.subplots(figsize=(10,5))
ax.pie(ab, labels=ab.index, autopct='%1.1f%%', radius=0.9, wedgeprops=dict(width=0.5))
ax.axis('equal')


plt.show()

# %%
x = df['Category']
y = df['Size']

plt.figure(figsize=(10,5))
plt.scatter(x,y)
plt.xlabel('Category')
plt.ylabel('Size')
plt.title('Scatter Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = df['Category']
#       2 y = df['Size']
#       4 plt.figure(figsize=(10,5))
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df, x='ship-state', color='orange')
plt.xticks(rotation=90)
plt.xlabel('state')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Vereficação de vendas por estados.

# %%
state_top = df['ship-state'].value_counts().head(10)

plt.figure(figsize=(12,5))
sns.countplot(data=df[df['ship-state'].isin(state_top.index)], x='ship-state')
plt.xticks(rotation=45)
plt.title('Sales by States')
plt.xlabel('state')
plt.ylabel('count')
plt.show()

# %% [markdown]
# No gráfico acima que o estado com a maior taxa de vendas na amazon é o estado de 'Maharashtra', e o produto com maior número de vendas é T-shirt.
